# %% [markdown]
# Experiment 2

# %%
import pandas as pd
df=pd.read_csv("Automobile_dataset_cleaned.csv")
df.head(10)
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
# 5          2                122         audi        std          two
# 6          1                158         audi        std         four
# 7          1                122         audi        std         four
# 8          1                158         audi      turbo         four
# 9          2                192          bmw        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# ...

# %%
df.drop('symboling',axis='columns',inplace=True)

# %%
df.head(10)
# Out:
#    normalized-losses         make aspiration num-of-doors   body-style  \
# 0                122  alfa-romero        std          two  convertible
# 1                122  alfa-romero        std          two  convertible
# 2                122  alfa-romero        std          two    hatchback
# 3                164         audi        std         four        sedan
# 4                164         audi        std         four        sedan
# 5                122         audi        std          two        sedan
# 6                158         audi        std         four        sedan
# 7                122         audi        std         four        wagon
# 8                158         audi      turbo         four        sedan
# 9                192          bmw        std          two        sedan
#
#   drive-wheels engine-location  wheel-base    length     width  ...  \
# 0          rwd           front        88.6  0.811148  0.890278  ...
# ...

# %%
df.tail(5)
# Out:
#      normalized-losses   make aspiration num-of-doors body-style drive-wheels  \
# 196                 95  volvo        std         four      sedan          rwd
# 197                 95  volvo      turbo         four      sedan          rwd
# 198                 95  volvo        std         four      sedan          rwd
# 199                 95  volvo      turbo         four      sedan          rwd
# 200                 95  volvo      turbo         four      sedan          rwd
#
#     engine-location  wheel-base    length     width  ...  compression-ratio  \
# 196           front       109.1  0.907256  0.956944  ...                9.5
# 197           front       109.1  0.907256  0.955556  ...                8.7
# 198           front       109.1  0.907256  0.956944  ...                8.8
# 199           front       109.1  0.907256  0.956944  ...               23.0
# 200           front       109.1  0.907256  0.956944  ...                9.5
#
# ...

# %%
o1=df.groupby('make')
toyotadf=o1.get_group('toyota')
toyotadf
# Out:
#      normalized-losses    make aspiration num-of-doors   body-style  \
# 146                 87  toyota        std          two    hatchback
# 147                 87  toyota        std          two    hatchback
# 148                 74  toyota        std         four    hatchback
# 149                 77  toyota        std         four        wagon
# 150                 81  toyota        std         four        wagon
# 151                 91  toyota        std         four        wagon
# 152                 91  toyota        std         four        sedan
# 153                 91  toyota        std         four    hatchback
# 154                 91  toyota        std         four        sedan
# 155                 91  toyota        std         four    hatchback
# 156                 91  toyota        std         four        sedan
# 157                 91  toyota        std         four    hatchback
# 158                 91  toyota        std         four        sedan
# ...

# %%
df['make'].value_counts()
# Out:
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# isuzu             2
# renault           2
# mercury           1
# Name: count, dtype: int64

# %%
car_Manufacturers = df.groupby('make')
pricedf = car_Manufacturers[['make', 'price']].max()
pricedf
# Out:
#                         make    price
# make
# alfa-romero      alfa-romero  16500.0
# audi                    audi  23875.0
# bmw                      bmw  41315.0
# chevrolet          chevrolet   6575.0
# dodge                  dodge  12964.0
# honda                  honda  12945.0
# isuzu                  isuzu  11048.0
# jaguar                jaguar  36000.0
# mazda                  mazda  18344.0
# mercedes-benz  mercedes-benz  45400.0
# mercury              mercury  16503.0
# mitsubishi        mitsubishi  14869.0
# nissan                nissan  19699.0
# peugot                peugot  18150.0
# plymouth            plymouth  12764.0
# porsche              porsche  37028.0
# renault              renault   9895.0
# saab                    saab  18620.0
# subaru                subaru  11694.0
# toyota                toyota  17669.0
# volkswagen        volkswagen  13845.0
# volvo                  volvo  22625.0

# %%
car_Manufacturers = df.groupby('make')
basedf = car_Manufacturers['wheel-base'].mean()
basedf
# Out:
# make
# alfa-romero       90.566667
# audi             102.733333
# bmw              103.162500
# chevrolet         92.466667
# dodge             95.011111
# honda             94.330769
# isuzu             95.150000
# jaguar           109.333333
# mazda             97.017647
# mercedes-benz    110.925000
# mercury          102.700000
# mitsubishi        95.353846
# nissan            95.722222
# peugot           110.200000
# plymouth          95.385714
# porsche           90.750000
# renault           96.100000
# saab              99.100000
# subaru            96.175000
# toyota            98.103125
# volkswagen        97.608333
# volvo            106.481818
# Name: wheel-base, dtype: float64

# %%
carsdf=df.sort_values(by=['price'])
carsdf.head(5)
# Out:
#      normalized-losses        make aspiration num-of-doors body-style  \
# 134                 83      subaru        std          two  hatchback
# 17                 121   chevrolet        std          two  hatchback
# 47                 104       mazda        std          two  hatchback
# 146                 87      toyota        std          two  hatchback
# 73                 161  mitsubishi        std          two  hatchback
#
#     drive-wheels engine-location  wheel-base    length     width  ...  \
# 134          fwd           front        93.7  0.753964  0.880556  ...
# 17           fwd           front        88.4  0.678039  0.837500  ...
# 47           fwd           front        93.1  0.764536  0.891667  ...
# 146          fwd           front        95.7  0.762614  0.883333  ...
# 73           fwd           front        93.7  0.755887  0.894444  ...
#
#      compression-ratio  horsepower peak-rpm city-mpg  highway-mpg   price  \
# ...
